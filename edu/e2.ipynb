# %%
import numpy as np
import os

os.environ['CUDA_VISIBLE_DEVICES'] = '1'
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

# %%
actions = [
    '안녕하세요', '감사합니다', '사랑합니다', '어머니', '아버지', '동생', '잘', '못', '간다', '나',
    '이름', '만나다', '반갑다', '부탁', '학교', '생일', '월', '일', '나이', '복습', '학습', '눈치', '오다', '말', '곱다',
    'ㄱ', 'ㄴ', 'ㄷ', 'ㄹ', 'ㅁ', 'ㅂ', 'ㅅ', 'ㅇ', 'ㅈ', 'ㅊ', 'ㅋ', 'ㅌ', 'ㅍ', 'ㅎ',
    'ㅏ', 'ㅑ', 'ㅓ', 'ㅕ', 'ㅗ', 'ㅛ', 'ㅜ', 'ㅠ', 'ㅡ', 'ㅣ',
    'ㅐ', 'ㅒ', 'ㅔ', 'ㅖ', 'ㅢ', 'ㅚ', 'ㅟ'
]

data = np.concatenate([
    np.load('dataset/seq_안녕하세요.npy'),
    np.load('dataset/seq_감사합니다.npy'),
    np.load('dataset/seq_사랑합니다.npy'),
    np.load('dataset/seq_어머니.npy'),
    np.load('dataset/seq_아버지.npy'),
    np.load('dataset/seq_동생.npy'),
    np.load('dataset/seq_잘.npy'),
    np.load('dataset/seq_못.npy'),
    np.load('dataset/seq_간다.npy'),
    np.load('dataset/seq_나.npy'),
    np.load('dataset/seq_이름.npy'),
    np.load('dataset/seq_만나다.npy'),
    np.load('dataset/seq_반갑다.npy'),
    np.load('dataset/seq_부탁.npy'),
    np.load('dataset/seq_학교.npy'),
    np.load('dataset/seq_생일.npy'),
    np.load('dataset/seq_월.npy'),
    np.load('dataset/seq_일.npy'),
    np.load('dataset/seq_나이.npy'),
    np.load('dataset/seq_복습.npy'),
    np.load('dataset/seq_학습.npy'),
    np.load('dataset/seq_눈치.npy'),
    np.load('dataset/seq_오다.npy'),
    np.load('dataset/seq_말.npy'),
    np.load('dataset/seq_곱다.npy'),
    np.load('dataset/seq_ㄱ.npy'),
    np.load('dataset/seq_ㄴ.npy'),
    np.load('dataset/seq_ㄷ.npy'),
    np.load('dataset/seq_ㄹ.npy'),
    np.load('dataset/seq_ㅁ.npy'),
    np.load('dataset/seq_ㅂ.npy'),
    np.load('dataset/seq_ㅅ.npy'),
    np.load('dataset/seq_ㅇ.npy'),
    np.load('dataset/seq_ㅈ.npy'),
    np.load('dataset/seq_ㅊ.npy'),
    np.load('dataset/seq_ㅋ.npy'),
    np.load('dataset/seq_ㅌ.npy'),
    np.load('dataset/seq_ㅍ.npy'),
    np.load('dataset/seq_ㅎ.npy'),
    np.load('dataset/seq_ㅏ.npy'),
    np.load('dataset/seq_ㅑ.npy'),
    np.load('dataset/seq_ㅓ.npy'),
    np.load('dataset/seq_ㅕ.npy'),
    np.load('dataset/seq_ㅗ.npy'),
    np.load('dataset/seq_ㅛ.npy'),
    np.load('dataset/seq_ㅜ.npy'),
    np.load('dataset/seq_ㅠ.npy'),
    np.load('dataset/seq_ㅡ.npy'),
    np.load('dataset/seq_ㅣ.npy'),
    np.load('dataset/seq_ㅐ.npy'),
    np.load('dataset/seq_ㅒ.npy'),
    np.load('dataset/seq_ㅔ.npy'),
    np.load('dataset/seq_ㅖ.npy'),
    np.load('dataset/seq_ㅢ.npy'),
    np.load('dataset/seq_ㅚ.npy'),
    np.load('dataset/seq_ㅟ.npy')
], axis=0)

data.shape
# Out:
# (23036, 30, 226)

# %%
x_data = data[:, :, :-1]
labels = data[:, 0, -1]

print(x_data.shape)
print(labels.shape)
# Out:
# (23036, 30, 225)
# (23036,)

# %%
import numpy as np

print(np.max(labels))
# Out:
# 56.0

# %%
from tensorflow.keras.utils import to_categorical

labels = np.where(labels == 56, 55, labels)
y_data = to_categorical(labels, num_classes=len(actions))
y_data.shape
# Out:
# (23036, 56)

# %%
from sklearn.model_selection import train_test_split

x_data = x_data.astype(np.float32)
y_data = y_data.astype(np.float32)

x_train, x_val, y_train, y_val = train_test_split(x_data, y_data, test_size=0.1, random_state=2021)

print(x_train.shape, y_train.shape)
print(x_val.shape, y_val.shape)
# Out:
# (20732, 30, 225) (20732, 56)
# (2304, 30, 225) (2304, 56)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

model = Sequential([
    LSTM(64, activation='relu', input_shape=x_train.shape[1:3]),
    Dense(32, activation='relu'),
    Dense(len(actions), activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])
model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\junseok\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\rnn\lstm.py:148: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\junseok\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                74240
#
#  dense (Dense)               (None, 32)                2080
#
#  dense_1 (Dense)             (None, 56)                1848
#
# =================================================================
# Total params: 78168 (305.34 KB)
# Trainable params: 78168 (305.34 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

history = model.fit(
    x_train,
    y_train,
    validation_data=(x_val, y_val),
    epochs=200,
    callbacks=[
        ModelCheckpoint('models/final.h5', monitor='val_acc', verbose=1, save_best_only=True, mode='auto'),
        ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=20, verbose=1, mode='auto'),
        EarlyStopping(monitor='val_acc', patience=30, verbose=1, restore_best_weights=True)
    ]
)
# Out:
# Epoch 1/200
# WARNING:tensorflow:From c:\Users\junseok\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\junseok\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 648/648 [==============================] - ETA: 0s - loss: 1.9594 - acc: 0.4223
# Epoch 1: val_acc improved from -inf to 0.68793, saving model to models\final.h5
# 648/648 [==============================] - 17s 22ms/step - loss: 1.9594 - acc: 0.4223 - val_loss: 0.9243 - val_acc: 0.6879 - lr: 0.0010
# Epoch 2/200
#   4/648 [..............................] - ETA: 10s - loss: 0.8926 - acc: 0.7031
# c:\Users\junseok\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 646/648 [============================>.] - ETA: 0s - loss: 0.7156 - acc: 0.7582
# Epoch 2: val_acc improved from 0.68793 to 0.82943, saving model to models\final.h5
# 648/648 [==============================] - 11s 17ms/step - loss: 0.7151 - acc: 0.7585 - val_loss: 0.4870 - val_acc: 0.8294 - lr: 0.0010
# Epoch 3/200
# 647/648 [============================>.] - ETA: 0s - loss: 0.4218 - acc: 0.8518
# Epoch 3: val_acc improved from 0.82943 to 0.89193, saving model to models\final.h5
# 648/648 [==============================] - 12s 18ms/step - loss: 0.4216 - acc: 0.8518 - val_loss: 0.3073 - val_acc: 0.8919 - lr: 0.0010
# Epoch 4/200
# 648/648 [==============================] - ETA: 0s - loss: 0.3239 - acc: 0.8865
# Epoch 4: val_acc improved from 0.89193 to 0.92925, saving model to models\final.h5
# 648/648 [==============================] - 15s 23ms/step - loss: 0.3239 - acc: 0.8865 - val_loss: 0.2142 - val_acc: 0.9293 - lr: 0.0010
# Epoch 5/200
# 648/648 [==============================] - ETA: 0s - loss: 0.2370 - acc: 0.9177
# Epoch 5: val_acc improved from 0.92925 to 0.94835, saving model to models\final.h5
# 648/648 [==============================] - 12s 18ms/step - loss: 0.2370 - acc: 0.9177 - val_loss: 0.1537 - val_acc: 0.9484 - lr: 0.0010
# Epoch 6/200
# 646/648 [============================>.] - ETA: 0s - loss: 0.1971 - acc: 0.9327
# Epoch 6: val_acc improved from 0.94835 to 0.94922, saving model to models\final.h5
# 648/648 [==============================] - 13s 20ms/step - loss: 0.1966 - acc: 0.9329 - val_loss: 0.1565 - val_acc: 0.9492 - lr: 0.0010
# Epoch 7/200
# 646/648 [============================>.] - ETA: 0s - loss: 0.1502 - acc: 0.9490
# Epoch 7: val_acc did not improve from 0.94922
# 648/648 [==============================] - 11s 17ms/step - loss: 0.1503 - acc: 0.9490 - val_loss: 0.2154 - val_acc: 0.9249 - lr: 0.0010
# Epoch 8/200
# 647/648 [============================>.] - ETA: 0s - loss: 0.1372 - acc: 0.9543
# Epoch 8: val_acc did not improve from 0.94922
# 648/648 [==============================] - 12s 18ms/step - loss: 0.1371 - acc: 0.9543 - val_loss: 0.2187 - val_acc: 0.9188 - lr: 0.0010
# Epoch 9/200
# 648/648 [==============================] - ETA: 0s - loss: 0.1466 - acc: 0.9531
# Epoch 9: val_acc improved from 0.94922 to 0.96311, saving model to models\final.h5
# 648/648 [==============================] - 13s 20ms/step - loss: 0.1466 - acc: 0.9531 - val_loss: 0.1221 - val_acc: 0.9631 - lr: 0.0010
# Epoch 10/200
# 646/648 [============================>.] - ETA: 0s - loss: 0.1062 - acc: 0.9668
# Epoch 10: val_acc did not improve from 0.96311
# 648/648 [==============================] - 11s 17ms/step - loss: 0.1066 - acc: 0.9667 - val_loss: 0.1133 - val_acc: 0.9609 - lr: 0.0010
# Epoch 11/200
# 646/648 [============================>.] - ETA: 0s - loss: 0.0963 - acc: 0.9688
# Epoch 11: val_acc improved from 0.96311 to 0.96745, saving model to models\final.h5
# 648/648 [==============================] - 13s 21ms/step - loss: 0.0962 - acc: 0.9689 - val_loss: 0.0957 - val_acc: 0.9674 - lr: 0.0010
# Epoch 12/200
# 646/648 [============================>.] - ETA: 0s - loss: 0.0816 - acc: 0.9745
# Epoch 12: val_acc improved from 0.96745 to 0.98220, saving model to models\final.h5
# 648/648 [==============================] - 11s 17ms/step - loss: 0.0814 - acc: 0.9746 - val_loss: 0.0562 - val_acc: 0.9822 - lr: 0.0010
# Epoch 13/200
# 646/648 [============================>.] - ETA: 0s - loss: 0.0853 - acc: 0.9736
# Epoch 13: val_acc improved from 0.98220 to 0.99219, saving model to models\final.h5
# 648/648 [==============================] - 12s 18ms/step - loss: 0.0853 - acc: 0.9736 - val_loss: 0.0435 - val_acc: 0.9922 - lr: 0.0010
# Epoch 14/200
# 646/648 [============================>.] - ETA: 0s - loss: 0.0983 - acc: 0.9691
# Epoch 14: val_acc did not improve from 0.99219
# 648/648 [==============================] - 13s 19ms/step - loss: 0.0981 - acc: 0.9692 - val_loss: 0.0607 - val_acc: 0.9792 - lr: 0.0010
# Epoch 15/200
# 646/648 [============================>.] - ETA: 0s - loss: 0.0581 - acc: 0.9821
# Epoch 15: val_acc did not improve from 0.99219
# 648/648 [==============================] - 10s 16ms/step - loss: 0.0580 - acc: 0.9821 - val_loss: 0.0383 - val_acc: 0.9865 - lr: 0.0010
# Epoch 16/200
# 648/648 [==============================] - ETA: 0s - loss: 0.0663 - acc: 0.9791
# Epoch 16: val_acc improved from 0.99219 to 0.99392, saving model to models\final.h5
# 648/648 [==============================] - 14s 21ms/step - loss: 0.0663 - acc: 0.9791 - val_loss: 0.0291 - val_acc: 0.9939 - lr: 0.0010
# Epoch 17/200
# 645/648 [============================>.] - ETA: 0s - loss: 0.0509 - acc: 0.9839
# Epoch 17: val_acc did not improve from 0.99392
# 648/648 [==============================] - 11s 17ms/step - loss: 0.0508 - acc: 0.9839 - val_loss: 0.0332 - val_acc: 0.9883 - lr: 0.0010
# Epoch 18/200
# 646/648 [============================>.] - ETA: 0s - loss: 0.0645 - acc: 0.9806
# Epoch 18: val_acc did not improve from 0.99392
# 648/648 [==============================] - 12s 18ms/step - loss: 0.0646 - acc: 0.9806 - val_loss: 0.1021 - val_acc: 0.9679 - lr: 0.0010
# Epoch 19/200
# 648/648 [==============================] - ETA: 0s - loss: 0.0831 - acc: 0.9757
# Epoch 19: val_acc improved from 0.99392 to 0.99826, saving model to models\final.h5
# 648/648 [==============================] - 12s 19ms/step - loss: 0.0831 - acc: 0.9757 - val_loss: 0.0097 - val_acc: 0.9983 - lr: 0.0010
# Epoch 20/200
# 646/648 [============================>.] - ETA: 0s - loss: 0.0595 - acc: 0.9813
# Epoch 20: val_acc did not improve from 0.99826
# 648/648 [==============================] - 12s 19ms/step - loss: 0.0595 - acc: 0.9813 - val_loss: 0.0310 - val_acc: 0.9909 - lr: 0.0010
# Epoch 21/200
# 646/648 [============================>.] - ETA: 0s - loss: 0.0458 - acc: 0.9872
# Epoch 21: val_acc did not improve from 0.99826
# 648/648 [==============================] - 13s 20ms/step - loss: 0.0457 - acc: 0.9873 - val_loss: 0.0150 - val_acc: 0.9974 - lr: 0.0010
# Epoch 22/200
# 645/648 [============================>.] - ETA: 0s - loss: 0.0464 - acc: 0.9858
# Epoch 22: val_acc did not improve from 0.99826
# 648/648 [==============================] - 12s 18ms/step - loss: 0.0465 - acc: 0.9858 - val_loss: 0.0384 - val_acc: 0.9900 - lr: 0.0010
# Epoch 23/200
# 647/648 [============================>.] - ETA: 0s - loss: 0.0386 - acc: 0.9885
# Epoch 23: val_acc did not improve from 0.99826
# 648/648 [==============================] - 14s 21ms/step - loss: 0.0387 - acc: 0.9884 - val_loss: 0.0235 - val_acc: 0.9935 - lr: 0.0010
# Epoch 24/200
# 648/648 [==============================] - ETA: 0s - loss: 0.0735 - acc: 0.9761
# Epoch 24: val_acc improved from 0.99826 to 0.99957, saving model to models\final.h5
# 648/648 [==============================] - 13s 21ms/step - loss: 0.0735 - acc: 0.9761 - val_loss: 0.0066 - val_acc: 0.9996 - lr: 0.0010
# Epoch 25/200
# 646/648 [============================>.] - ETA: 0s - loss: 0.0058 - acc: 0.9990
# Epoch 25: val_acc improved from 0.99957 to 1.00000, saving model to models\final.h5
# 648/648 [==============================] - 14s 21ms/step - loss: 0.0057 - acc: 0.9990 - val_loss: 0.0022 - val_acc: 1.0000 - lr: 0.0010
# Epoch 26/200
# 646/648 [============================>.] - ETA: 0s - loss: 0.0621 - acc: 0.9797
# Epoch 26: val_acc did not improve from 1.00000
# 648/648 [==============================] - 12s 19ms/step - loss: 0.0621 - acc: 0.9797 - val_loss: 0.0851 - val_acc: 0.9688 - lr: 0.0010
# Epoch 27/200
# 647/648 [============================>.] - ETA: 0s - loss: 0.0193 - acc: 0.9948
# Epoch 27: val_acc did not improve from 1.00000
# 648/648 [==============================] - 10s 16ms/step - loss: 0.0193 - acc: 0.9948 - val_loss: 0.0649 - val_acc: 0.9714 - lr: 0.0010
# Epoch 28/200
# 648/648 [==============================] - ETA: 0s - loss: 0.0363 - acc: 0.9890
# Epoch 28: val_acc did not improve from 1.00000
# 648/648 [==============================] - 13s 20ms/step - loss: 0.0363 - acc: 0.9890 - val_loss: 0.2621 - val_acc: 0.9145 - lr: 0.0010
# Epoch 29/200
# 648/648 [==============================] - ETA: 0s - loss: 0.0430 - acc: 0.9859
# Epoch 29: val_acc did not improve from 1.00000
# 648/648 [==============================] - 11s 17ms/step - loss: 0.0430 - acc: 0.9859 - val_loss: 0.0073 - val_acc: 0.9996 - lr: 0.0010
# Epoch 30/200
# 648/648 [==============================] - ETA: 0s - loss: 0.0160 - acc: 0.9950
# Epoch 30: val_acc did not improve from 1.00000
# 648/648 [==============================] - 13s 20ms/step - loss: 0.0160 - acc: 0.9950 - val_loss: 0.0068 - val_acc: 0.9978 - lr: 0.0010
# Epoch 31/200
# 645/648 [============================>.] - ETA: 0s - loss: 0.0585 - acc: 0.9828
# Epoch 31: val_acc did not improve from 1.00000
# 648/648 [==============================] - 12s 19ms/step - loss: 0.0594 - acc: 0.9825 - val_loss: 0.3116 - val_acc: 0.8915 - lr: 0.0010
# Epoch 32/200
# 648/648 [==============================] - ETA: 0s - loss: 0.0155 - acc: 0.9952
# Epoch 32: val_acc did not improve from 1.00000
# 648/648 [==============================] - 13s 20ms/step - loss: 0.0155 - acc: 0.9952 - val_loss: 0.0100 - val_acc: 0.9965 - lr: 0.0010
# Epoch 33/200
# 648/648 [==============================] - ETA: 0s - loss: 0.0439 - acc: 0.9869
# Epoch 33: val_acc did not improve from 1.00000
# 648/648 [==============================] - 13s 21ms/step - loss: 0.0439 - acc: 0.9869 - val_loss: 0.0252 - val_acc: 0.9918 - lr: 0.0010
# Epoch 34/200
# 645/648 [============================>.] - ETA: 0s - loss: 0.0251 - acc: 0.9921
# Epoch 34: val_acc did not improve from 1.00000
# 648/648 [==============================] - 11s 16ms/step - loss: 0.0252 - acc: 0.9919 - val_loss: 0.0814 - val_acc: 0.9735 - lr: 0.0010
# Epoch 35/200
# 648/648 [==============================] - ETA: 0s - loss: 0.0222 - acc: 0.9940
# Epoch 35: val_acc did not improve from 1.00000
# 648/648 [==============================] - 12s 18ms/step - loss: 0.0222 - acc: 0.9940 - val_loss: 0.0089 - val_acc: 0.9965 - lr: 0.0010
# Epoch 36/200
# 648/648 [==============================] - ETA: 0s - loss: 0.0261 - acc: 0.9929
# Epoch 36: val_acc did not improve from 1.00000
# 648/648 [==============================] - 12s 18ms/step - loss: 0.0261 - acc: 0.9929 - val_loss: 0.0030 - val_acc: 0.9996 - lr: 0.0010
# Epoch 37/200
# 647/648 [============================>.] - ETA: 0s - loss: 0.0319 - acc: 0.9906
# Epoch 37: val_acc did not improve from 1.00000
# 648/648 [==============================] - 12s 19ms/step - loss: 0.0319 - acc: 0.9906 - val_loss: 0.0023 - val_acc: 0.9996 - lr: 0.0010
# Epoch 38/200
# 646/648 [============================>.] - ETA: 0s - loss: 5.0756e-04 - acc: 1.0000
# Epoch 38: val_acc did not improve from 1.00000
# 648/648 [==============================] - 13s 20ms/step - loss: 5.0658e-04 - acc: 1.0000 - val_loss: 0.0016 - val_acc: 0.9996 - lr: 0.0010
# Epoch 39/200
# 647/648 [============================>.] - ETA: 0s - loss: 2.8431e-04 - acc: 1.0000
# Epoch 39: val_acc did not improve from 1.00000
# 648/648 [==============================] - 11s 18ms/step - loss: 2.8420e-04 - acc: 1.0000 - val_loss: 0.0014 - val_acc: 0.9996 - lr: 0.0010
# Epoch 40/200
# 646/648 [============================>.] - ETA: 0s - loss: 0.0420 - acc: 0.9894
# Epoch 40: val_acc did not improve from 1.00000
# 648/648 [==============================] - 13s 19ms/step - loss: 0.0419 - acc: 0.9894 - val_loss: 0.0246 - val_acc: 0.9944 - lr: 0.0010
# Epoch 41/200
# 648/648 [==============================] - ETA: 0s - loss: 0.0507 - acc: 0.9847
# Epoch 41: val_acc did not improve from 1.00000
# 648/648 [==============================] - 12s 19ms/step - loss: 0.0507 - acc: 0.9847 - val_loss: 0.0025 - val_acc: 0.9996 - lr: 0.0010
# Epoch 42/200
# 647/648 [============================>.] - ETA: 0s - loss: 0.0214 - acc: 0.9941
# Epoch 42: val_acc did not improve from 1.00000
# 648/648 [==============================] - 14s 21ms/step - loss: 0.0213 - acc: 0.9941 - val_loss: 0.0087 - val_acc: 0.9987 - lr: 0.0010
# Epoch 43/200
# 646/648 [============================>.] - ETA: 0s - loss: 0.0313 - acc: 0.9903
# Epoch 43: val_acc did not improve from 1.00000
# 648/648 [==============================] - 13s 20ms/step - loss: 0.0312 - acc: 0.9903 - val_loss: 0.0029 - val_acc: 1.0000 - lr: 0.0010
# Epoch 44/200
# 645/648 [============================>.] - ETA: 0s - loss: 0.0011 - acc: 1.0000
# Epoch 44: val_acc did not improve from 1.00000
# 648/648 [==============================] - 10s 16ms/step - loss: 0.0011 - acc: 1.0000 - val_loss: 0.0018 - val_acc: 0.9996 - lr: 0.0010
# Epoch 45/200
# 646/648 [============================>.] - ETA: 0s - loss: 3.9118e-04 - acc: 1.0000
# Epoch 45: val_acc did not improve from 1.00000
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 648/648 [==============================] - 12s 19ms/step - loss: 3.9032e-04 - acc: 1.0000 - val_loss: 3.6507e-04 - val_acc: 1.0000 - lr: 0.0010
# Epoch 46/200
# 646/648 [============================>.] - ETA: 0s - loss: 1.9045e-04 - acc: 1.0000
# Epoch 46: val_acc did not improve from 1.00000
# 648/648 [==============================] - 12s 19ms/step - loss: 1.9013e-04 - acc: 1.0000 - val_loss: 4.8438e-04 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 47/200
# 646/648 [============================>.] - ETA: 0s - loss: 1.3928e-04 - acc: 1.0000
# Epoch 47: val_acc did not improve from 1.00000
# 648/648 [==============================] - 14s 22ms/step - loss: 1.3946e-04 - acc: 1.0000 - val_loss: 3.0241e-04 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 48/200
# 647/648 [============================>.] - ETA: 0s - loss: 1.1219e-04 - acc: 1.0000
# Epoch 48: val_acc did not improve from 1.00000
# 648/648 [==============================] - 14s 21ms/step - loss: 1.1218e-04 - acc: 1.0000 - val_loss: 5.1378e-04 - val_acc: 0.9996 - lr: 5.0000e-04
# Epoch 49/200
# 648/648 [==============================] - ETA: 0s - loss: 8.8111e-05 - acc: 1.0000
# Epoch 49: val_acc did not improve from 1.00000
# 648/648 [==============================] - 12s 19ms/step - loss: 8.8111e-05 - acc: 1.0000 - val_loss: 2.1751e-04 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 50/200
# 646/648 [============================>.] - ETA: 0s - loss: 5.8129e-05 - acc: 1.0000
# Epoch 50: val_acc did not improve from 1.00000
# 648/648 [==============================] - 13s 20ms/step - loss: 5.8028e-05 - acc: 1.0000 - val_loss: 2.2915e-04 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 51/200
# 648/648 [==============================] - ETA: 0s - loss: 4.3365e-05 - acc: 1.0000
# Epoch 51: val_acc did not improve from 1.00000
# 648/648 [==============================] - 12s 19ms/step - loss: 4.3365e-05 - acc: 1.0000 - val_loss: 1.9538e-04 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 52/200
# 648/648 [==============================] - ETA: 0s - loss: 3.1037e-05 - acc: 1.0000
# Epoch 52: val_acc did not improve from 1.00000
# 648/648 [==============================] - 14s 21ms/step - loss: 3.1037e-05 - acc: 1.0000 - val_loss: 1.2477e-04 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 53/200
# 646/648 [============================>.] - ETA: 0s - loss: 2.5184e-05 - acc: 1.0000
# Epoch 53: val_acc did not improve from 1.00000
# 648/648 [==============================] - 12s 18ms/step - loss: 2.5135e-05 - acc: 1.0000 - val_loss: 1.6848e-04 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 54/200
# 648/648 [==============================] - ETA: 0s - loss: 2.0672e-05 - acc: 1.0000
# Epoch 54: val_acc did not improve from 1.00000
# 648/648 [==============================] - 11s 17ms/step - loss: 2.0672e-05 - acc: 1.0000 - val_loss: 1.1622e-04 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 55/200
# 648/648 [==============================] - ETA: 0s - loss: 0.0284 - acc: 0.9932
# Epoch 55: val_acc did not improve from 1.00000
# Restoring model weights from the end of the best epoch: 25.
# 648/648 [==============================] - 13s 20ms/step - loss: 0.0284 - acc: 0.9932 - val_loss: 0.0232 - val_acc: 0.9970 - lr: 5.0000e-04
# Epoch 55: early stopping

# %%
import matplotlib.pyplot as plt

fig, loss_ax = plt.subplots(figsize=(16, 10))
acc_ax = loss_ax.twinx()

loss_ax.plot(history.history['loss'], 'y', label='train loss')
loss_ax.plot(history.history['val_loss'], 'r', label='val loss')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
loss_ax.legend(loc='upper left')

acc_ax.plot(history.history['acc'], 'b', label='train acc')
acc_ax.plot(history.history['val_acc'], 'g', label='val acc')
acc_ax.set_ylabel('accuracy')
acc_ax.legend(loc='upper left')

plt.show()

# %%
from sklearn.metrics import multilabel_confusion_matrix
from tensorflow.keras.models import load_model

model = load_model('models/final.h5')

y_pred = model.predict(x_val)

multilabel_confusion_matrix(np.argmax(y_val, axis=1), np.argmax(y_pred, axis=1))
# Out:
# 72/72 [==============================] - 1s 6ms/step
# array([[[2265,    0],
#         [   0,   39]],
#
#        [[2261,    0],
#         [   0,   43]],
#
#        [[2269,    0],
#         [   0,   35]],
#
#        [[2263,    0],
#         [   0,   41]],
#
#        [[2249,    0],
#         [   0,   55]],
#
#        [[2258,    0],
#         [   0,   46]],
#
#        [[2264,    0],
#         [   0,   40]],
#
#        [[2265,    0],
#         [   0,   39]],
#
#        [[2273,    0],
#         [   0,   31]],
#
#        [[2269,    0],
#         [   0,   35]],
#
#        [[2264,    0],
#         [   0,   40]],
#
#        [[2261,    0],
#         [   0,   43]],
#
#        [[2265,    0],
#         [   0,   39]],
#
#        [[2258,    0],
#         [   0,   46]],
#
#        [[2264,    0],
#         [   0,   40]],
#
#        [[2269,    0],
#         [   0,   35]],
#
#        [[2267,    0],
#         [   0,   37]],
#
#        [[2259,    0],
#         [   0,   45]],
#
#        [[2274,    0],
#         [   0,   30]],
#
#        [[2270,    0],
#         [   0,   34]],
#
#        [[2263,    0],
#         [   0,   41]],
#
#        [[2268,    0],
#         [   0,   36]],
#
#        [[2246,    0],
#         [   0,   58]],
#
#        [[2263,    0],
#         [   0,   41]],
#
#        [[2258,    0],
#         [   0,   46]],
#
#        [[2266,    0],
#         [   0,   38]],
#
#        [[2262,    0],
#         [   0,   42]],
#
#        [[2262,    0],
#         [   0,   42]],
#
#        [[2269,    0],
#         [   0,   35]],
#
#        [[2264,    0],
#         [   0,   40]],
#
#        [[2266,    0],
#         [   0,   38]],
#
#        [[2260,    0],
#         [   0,   44]],
#
#        [[2259,    0],
#         [   0,   45]],
#
#        [[2259,    0],
#         [   0,   45]],
#
#        [[2266,    0],
#         [   0,   38]],
#
#        [[2266,    0],
#         [   0,   38]],
#
#        [[2264,    0],
#         [   0,   40]],
#
#        [[2251,    0],
#         [   0,   53]],
#
#        [[2286,    0],
#         [   0,   18]],
#
#        [[2257,    0],
#         [   0,   47]],
#
#        [[2255,    0],
#         [   0,   49]],
#
#        [[2270,    0],
#         [   0,   34]],
#
#        [[2261,    0],
#         [   0,   43]],
#
#        [[2260,    0],
#         [   0,   44]],
#
#        [[2249,    0],
#         [   0,   55]],
#
#        [[2268,    0],
#         [   0,   36]],
#
#        [[2251,    0],
#         [   0,   53]],
#
#        [[2265,    0],
#         [   0,   39]],
#
#        [[2260,    0],
#         [   0,   44]],
#
#        [[2253,    0],
#         [   0,   51]],
#
#        [[2275,    0],
#         [   0,   29]],
#
#        [[2266,    0],
#         [   0,   38]],
#
#        [[2256,    0],
#         [   0,   48]],
#
#        [[2262,    0],
#         [   0,   42]],
#
#        [[2223,    0],
#         [   0,   81]]], dtype=int64)
